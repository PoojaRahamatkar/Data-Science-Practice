# %% [markdown]
# **Adult UCI Dataset Analysis**
#
# The adult UCI dataset is one of the popular datasets for practice. It is a **Supervised Binary Classification Problem.**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Load the data

# %%
df = pd.read_csv('adult.csv')

# %%
df.head(10)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
# 8   24           Private  369667  Some-college               10
# 9   55           Private  104996       7th-8th                4
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2  Married-civ-spouse    Protective-serv        Husband  White    Male
# 3  Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4       Never-married                  ?      Own-child  White  Female
# 5       Never-married      Other-service  Not-in-family  White    Male
# 6       Never-married                  ?      Unmarried  Black    Male
# 7  Married-civ-spouse     Prof-specialty        Husband  White    Male
# 8       Never-married      Other-service      Unmarried  White  Female
# 9  Married-civ-spouse       Craft-repair        Husband  White    Male
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0              40  United-States  <=50K
# 1             0             0              50  United-States  <=50K
# 2             0             0              40  United-States   >50K
# 3          7688             0              40  United-States   >50K
# 4             0             0              30  United-States  <=50K
# 5             0             0              30  United-States  <=50K
# 6             0             0              40  United-States  <=50K
# 7          3103             0              32  United-States   >50K
# 8             0             0              40  United-States  <=50K
# 9             0             0              10  United-States  <=50K

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.nunique()
# Out:
# age                   74
# workclass              9
# fnlwgt             28523
# education             16
# educational-num       16
# marital-status         7
# occupation            15
# relationship           6
# race                   5
# gender                 2
# capital-gain         123
# capital-loss          99
# hours-per-week        96
# native-country        42
# income                 2
# dtype: int64

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# **Value Count Function**
#
# value_counts() function returns object containing counts of unique values.

# %%
df['workclass'].value_counts()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
df['occupation'].value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
df['native-country'].value_counts()
# Out:
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# Nicaragua                        49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Hong                             30
# Thailand                         30
# Cambodia                         28
# Trinadad&Tobago                  27
# Laos                             23
# Yugoslavia                       23
# Outlying-US(Guam-USVI-etc)       23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
df['marital-status'].value_counts()
# Out:
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# Male      32650
# Female    16192
# Name: gender, dtype: int64

# %%
df['race'].value_counts()
# Out:
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
df['income'].value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %%
df['education'].value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
sns.countplot(df['income'], palette='coolwarm', hue='relationship', data = df)

# %% [markdown]
# **Filling ? Values**

# %%
## replace the values with mode
df['workclass']=df['workclass'].replace('?','Private')
df['occupation']=df['occupation'].replace('?','Prof-specialty')
df['native-country']=df['native-country'].replace('?','United-states')

# %%
df.head(8)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18           Private  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29           Private  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2  Married-civ-spouse    Protective-serv        Husband  White    Male
# 3  Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# 4       Never-married     Prof-specialty      Own-child  White  Female
# 5       Never-married      Other-service  Not-in-family  White    Male
# 6       Never-married     Prof-specialty      Unmarried  Black    Male
# 7  Married-civ-spouse     Prof-specialty        Husband  White    Male
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0             0             0              40  United-States  <=50K
# 1             0             0              50  United-States  <=50K
# 2             0             0              40  United-States   >50K
# 3          7688             0              40  United-States   >50K
# 4             0             0              30  United-States  <=50K
# 5             0             0              30  United-States  <=50K
# 6             0             0              40  United-States  <=50K
# 7          3103             0              32  United-States   >50K

# %% [markdown]
# **Feature Engineering**

# %%
# education Category
df.education = df.education.replace(['Preschool', '1st-4th', '5th-6th', '7th-8th', '9th', '10th', '11th', '12th'], 'school')
df.education = df.education.replace('HS-grad', 'high school')
df.education = df.education.replace(['Assoc-voc', 'Assoc-acdm', 'Prof-school', 'Some-college'], 'higher')
df.education = df.education.replace('Bachelors', 'undergrad')
df.education = df.education.replace('Masters', 'grad')
df.education = df.education.replace('Doctorate', 'doc')

# %%
# martial Status
df['marital-status'] = df['marital-status'].replace(['Married-civ-spouse', 'Married-AF-spouse'], 'married')
df['marital-status'] = df['marital-status'].replace(['Never-married'], 'not-married')
df['marital-status'] = df['marital-status'].replace(['Divorced', 'Separated', 'Widowed', 'Married-spouse-absent'], 'other')

# %%
df.income = df.income.replace('<=50K',0)
df.income = df.income.replace('>50K',1)

# %%
df.head()
# Out:
#    age  workclass  fnlwgt    education  educational-num marital-status  \
# 0   25    Private  226802       school                7    not-married
# 1   38    Private   89814  high school                9        married
# 2   28  Local-gov  336951       higher               12        married
# 3   44    Private  160323       higher               10        married
# 4   18    Private  103497       higher               10    not-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4     Prof-specialty    Own-child  White  Female             0             0
#
#    hours-per-week native-country  income
# 0              40  United-States       0
# 1              50  United-States       0
# 2              40  United-States       1
# 3              40  United-States       1
# 4              30  United-States       0

# %%
df['marital-status'].value_counts()
# Out:
# married        22416
# not-married    16117
# other          10309
# Name: marital-status, dtype: int64

# %%
df['education'].value_counts()
# Out:
# high school    15784
# higher         15374
# undergrad       8025
# school          6408
# grad            2657
# doc              594
# Name: education, dtype: int64

# %%
df.corr()
# Out:
#                       age    fnlwgt  educational-num  capital-gain  \
# age              1.000000 -0.076628         0.030940      0.077229
# fnlwgt          -0.076628  1.000000        -0.038761     -0.003706
# educational-num  0.030940 -0.038761         1.000000      0.125146
# capital-gain     0.077229 -0.003706         0.125146      1.000000
# capital-loss     0.056944 -0.004366         0.080972     -0.031441
# hours-per-week   0.071558 -0.013519         0.143689      0.082157
# income           0.230369 -0.006339         0.332613      0.223013
#
#                  capital-loss  hours-per-week    income
# age                  0.056944        0.071558  0.230369
# fnlwgt              -0.004366       -0.013519 -0.006339
# educational-num      0.080972        0.143689  0.332613
# capital-gain        -0.031441        0.082157  0.223013
# capital-loss         1.000000        0.054467  0.147554
# hours-per-week       0.054467        1.000000  0.227687
# income               0.147554        0.227687  1.000000

# %%
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# **Histogram**

# %%
df.hist(figsize=(12,12), layout=(3,3), sharex=False);

# %%
df.plot(kind='box', figsize=(12,12), layout=(3,3), sharex=False, subplots=True)
# Out:
# age                   AxesSubplot(0.125,0.657941;0.227941x0.222059)
# fnlwgt             AxesSubplot(0.398529,0.657941;0.227941x0.222059)
# educational-num    AxesSubplot(0.672059,0.657941;0.227941x0.222059)
# capital-gain          AxesSubplot(0.125,0.391471;0.227941x0.222059)
# capital-loss       AxesSubplot(0.398529,0.391471;0.227941x0.222059)
# hours-per-week     AxesSubplot(0.672059,0.391471;0.227941x0.222059)
# income                   AxesSubplot(0.125,0.125;0.227941x0.222059)
# dtype: object

# %% [markdown]
# **Plotly**

# %%
px.pie(df, values='educational-num', names='education', title='% of edu', color_discrete_sequence = px.colors.qualitative.T10)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c46e8713-7da9-4c3c-99be-580105e7d7dc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c46e8713-7da9-4c3c-99be-580105e7d7dc")) {                    Plotly.newPlot(                        "c46e8713-7da9-4c3c-99be-580105e7d7dc",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"education=%{label}<br>educational-num=%{value}<extra></extra>","labels":["school","high school","higher","higher","higher","school","high school","higher","higher","school","high school","undergrad","high school","high school","high school","grad","higher","high school","high school","doc","undergrad","higher","school","undergrad","undergrad","high school","high school","high school","high school","higher","higher","school","undergrad","higher","high school","high school","undergrad","school","school","high school","grad","higher","high school","school","higher","higher","school","higher","school","high school","higher","high school","higher","high school","school","higher","high school","undergrad","high school","high school","undergrad","higher","grad","high school","high school","undergrad","higher","higher","high school","high school","higher","higher","high school","higher","higher","school","high school","high school","high school","higher","higher","undergrad","higher","high school","higher","high school","school","high school","higher","grad","undergrad","school","grad","undergrad","grad","high school","undergrad","school","high school","high school","higher","higher","higher","school","high school","school","high school","high school","higher","high school","high school","higher","higher","high school","higher","high school","high school","school","high school","undergrad","undergrad","higher","higher","higher","high school","high school","doc","high school","high school","grad","higher","high school","high school","doc","high school","higher","high school","school","high school","school","grad","higher","high school","high school","grad","high school","higher","high school","undergrad","high school","higher","school","school","school","undergrad","higher","high school","undergrad","higher","undergrad","school","high school","high school","undergrad","grad","higher","doc","high school","high school","high school","high school","grad","undergrad","school","grad","higher","higher","higher","high school","higher","grad","higher","high school","undergrad","high school","higher","high school","high school","undergrad","high school","undergrad","undergrad","higher","school","high school","higher","higher","higher","high school","high school","higher","undergrad","undergrad","undergrad","higher","undergrad","school","high school","undergrad","higher","school","higher","higher","undergrad","undergrad","high school","high school","school","higher","undergrad","undergrad","high school","high school","high school","school","higher","undergrad","high school","school","higher","school","higher","grad","high school","high school","higher","higher","high school","higher","high school","high school","high school","higher","higher","higher","high school","high school","high school","high school","high school","higher","higher","undergrad","undergrad","undergrad","higher","higher","high school","high school","higher","higher","grad","higher","undergrad","grad","higher","high school","school","higher","school","high school","school","higher","grad","high school","high school","high school","school","undergrad","higher","high school","high school","high school","higher","undergrad","higher","high school","higher","higher","high school","high school","school","higher","school","higher","high school","school","high school","higher","high school"," ...

# %%
sns.countplot(df['education'], hue='gender', data=df, palette='seismic')

# %% [markdown]
# **Model Building**

# %%
x = df.drop(['income'], axis=1)
y = df['income']

# %% [markdown]
# **Feature Scaling**

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df1 = df.copy()
df1 = df1.apply(LabelEncoder().fit_transform)
df1.head()
# Out:
#    age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0    8          3   19329          4                6               1
# 1   21          3    4212          2                8               0
# 2   11          1   25340          3               11               0
# 3   27          3   11201          3                9               0
# 4    1          3    5411          3                9               1
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0           6             3     2       1             0             0
# 1           4             0     4       1             0             0
# 2          10             0     4       1             0             0
# 3           6             0     2       1            98             0
# 4           9             3     4       0             0             0
#
#    hours-per-week  native-country  income
# 0              39              38       0
# 1              49              38       0
# 2              39              38       1
# 3              39              38       1
# 4              29              38       0

# %%
ss = StandardScaler().fit(df1.drop('income', axis=1))

# %%
x = ss.transform(df1.drop('income', axis=1))
y = df['income']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state=40)

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr = LogisticRegression()

model = lr.fit(x_train, y_train)
prediction = model.predict(x_test)

print("Acc on Training Data: {:,.3f}".format(lr.score(x_train, y_train)))
print("Acc on test data: {:,.3f}".format(lr.score(x_test, y_test)))
# Out:
# Acc on Training Data: 0.838
# Acc on test data: 0.839

# %% [markdown]
# **Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

model1 = rfc.fit(x_train, y_train)
prediction1 = model1.predict(x_test)

print("Acc on training data : {:,.3f}".format(rfc.score(x_train, y_train)))
print("Acc on test data: {:,.3f}".format(rfc.score(x_test, y_test)))
# Out:
# Acc on training data : 1.000
# Acc on test data: 0.858

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print(confusion_matrix(y_test, prediction1))
# Out:
# [[10332   806]
#  [ 1278  2237]]

# %%
print(classification_report(y_test,prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91     11138
#            1       0.74      0.64      0.68      3515
#
#     accuracy                           0.86     14653
#    macro avg       0.81      0.78      0.80     14653
# weighted avg       0.85      0.86      0.85     14653

# %%
# Precision : tp/(tp+fp)
print('Precision=', 10332/(10332+1286))
# Out:
# Precision= 0.8893096918574626

# %%
# recall = tp/(tp+fn)
print("Recall=", 10332/(10332+806))
# Out:
# Recall= 0.9276351230023343

# %% [markdown]
# **For Other Class : 1(>50K)**

# %%
print("Precision=", 2229/(2229+806))
# Out:
# Precision= 0.7344316309719934

# %%
print("Recall", 2229/(2229+1286))
# Out:
# Recall 0.6341394025604552
