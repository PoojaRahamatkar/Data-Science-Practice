# %% [markdown]
# **Modin - Pandas**
#
# Modin is a drop-in replacement for pandas. While pandas is single-threaded, Modin lets you instantly speed up your workflows by scaling pandas.
#
# * How to spped up Pandas by 4X

# %%
## Read in the data with Modin

# !pip install Modin
import modin.pandas as pd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 761 kB 9.9 MB/s
# ...
#      |████████████████████████████████| 141 kB 43.1 MB/s
# ...

# %%
## Read in the data with pandas
import pandas as pd
import time

s = time.time()  # Returns the number of seconds passed since epoch.
df = pd.read_csv("wine.csv")
e = time.time()
print("Pandas Loading Time = {}".format(e-s))

s = time.time()
df = pd.read_csv("wine.csv")
e = time.time()
print("Modin Loading Time = {}".format(e-s))
# Out:
# Pandas Loading Time = 0.01537013053894043
# Modin Loading Time = 0.00476384162902832

# %%
import numpy as np

## random.randint :-  It create an array of specified shape and returns an integer number selected element from the specified range.
frame_data = np.random.randint(0,100, size=(2**10,2**8))
df = pd.DataFrame(frame_data)

# %%
df.shape
# Out:
# (1024, 256)

# %%
df.to_csv('test_31.csv')

# %%
pip install modin[dask]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 837 kB 14.0 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 54.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 44.0 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 1.3.0
#     Uninstalling cloudpickle-1.3.0:
#       Successfully uninstalled cloudpickle-1.3.0
#   Attempting uninstall: dask
#     Found existing installation: dask 2.12.0
#     Uninstalling dask-2.12.0:
#       Successfully uninstalled dask-2.12.0
#   Attempting uninstall: distributed
#     Found existing installation: distributed 1.25.3
#     Uninstalling distributed-1.25.3:
#       Successfully uninstalled distributed-1.25.3
# ...

# %%
# %%time

import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/MateLabs/Public-Datasets/master/Datasets/wine.csv')
# Out:
# CPU times: user 12.1 ms, sys: 1.86 ms, total: 14 ms
# Wall time: 222 ms

# %%
df
# Out:
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# 3      14.37        1.95  2.50               16.8        113           3.85
# 4      13.24        2.59  2.87               21.0        118           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5         95           1.68
# 174    13.40        3.91  2.48               23.0        102           1.80
# 175    13.27        4.28  2.26               20.0        120           1.59
# 176    13.17        2.59  2.37               20.0        120           1.65
# 177    14.13        4.10  2.74               24.5         96           2.05
#
# ...

# %%
# %%time

# !pip install modin[dask]
import modin.pandas as pd
pd.read_csv('https://raw.githubusercontent.com/MateLabs/Public-Datasets/master/Datasets/wine.csv')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# To remove this warning, run the following python code before doing dataframe operations:
#
#     from distributed import Client
#
#     client = Client()
#
# ...
#
# +-------------+--------+-----------+---------+
# | Package     | client | scheduler | workers |
# +-------------+--------+-----------+---------+
# | cloudpickle | 1.3.0  | 1.3.0     | 2.1.0   |
# +-------------+--------+-----------+---------+
# ...
# To request implementation, send an email to feature_requests@modin.org.
# CPU times: user 1.16 s, sys: 168 ms, total: 1.32 s
# Wall time: 8.26 s
#      Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  Total phenols  \
# 0      14.23        1.71  2.43               15.6        127           2.80
# 1      13.20        1.78  2.14               11.2        100           2.65
# 2      13.16        2.36  2.67               18.6        101           2.80
# ...

# %%
import time
import pandas as pd

df = pd.read_csv('test_31.csv')
s = time.time()
df = pd.concat([df for _ in range(100)])
e = time.time()
print("Modin Pandas Concat Time = {}".format(e-s))
# Out:
# Modin Pandas Concat Time = 0.1046452522277832

# %%
import time
import modin.pandas as pd
df = pd.read_csv('test_31.csv')
s = time.time()
df = pd.concat([df for _ in range(100)])
e = time.time()
print("Modin Pandas Concat Time = {}".format(e-s))
# Out:
# Modin Pandas Concat Time = 0.014864683151245117

# %%
## Sometime Modin is Faster than Original Libaraies of Pandas
